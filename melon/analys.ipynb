# %% [markdown]
# План: надо  1) перенести данные из json
#             2) написать функцию для фильтрации при переносе данных (дата, жанр, автор и т п)
#             3) ну и очев функции обработки массива - почитать методичку по статам и что-то понять
